# %%
import matplotlib.pyplot as plt
from sklearn import datasets
from sklearn.tree import DecisionTreeClassifier
from sklearn import tree

# %%
iris = datasets.load_iris()
X = iris.data
y = iris.target

# %%
clf = tree.DecisionTreeClassifier()
clf = clf.fit(X,y)

# %%
fig = plt.figure(figsize=(25,20))
tree.plot_tree(clf, filled = True, rounded = True, max_depth=3)
plt.show()

# %%
# !pip install graphviz
# Out:
# Requirement already satisfied: graphviz in c:\users\rosha\anaconda3\lib\site-packages (0.20)

# %%
import graphviz
data = tree.export_graphviz(clf,out_file = None,
                          feature_names=iris.feature_names,
                          class_names = iris.target_names,
                          filled=True)
graph = graphviz.Source(data, format='png')
graph

# %%
graph.render("decision_tree_graphviz")
# Out:
# 'decision_tree_graphviz.png'

# %%
from dtreeviz.trees import dtreeviz
tree = dtreeviz(clf, X, y,
               target_name = "target",
               feature_names = iris.feature_names,
               class_names = list(iris.target_names))
tree

# %%
tree.save("decision_tree.svg")
